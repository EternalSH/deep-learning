# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
# Number of embedding features 
n_embedding = 200 

with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))

    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
     # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    
     # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6616 0.0357 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5880 0.0280 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4876 0.0280 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6071 0.0280 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5212 0.0280 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5817 0.0279 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5345 0.0280 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5179 0.0279 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4756 0.0279 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4092 0.0280 sec/batch
# Nearest to were: checkers, clam, cerezo, seduction, softwood, introducing, zimbabwean, founded,
# Nearest to been: nonmetallic, constituent, northwest, ceeac, incarceration, leena, reappeared, vantaa,
# Nearest to by: limiting, travelin, fars, lemmon, disparities, chronometers, crossings, scriptures,
# Nearest to i: overweight, ipv, shop, correct, inaccurate, teaspoons, sisterhood, broch,
# Nearest to d: raoul, frysl, deponent, institutions, unforgiven, sukkah, undigested, alkane,
# Nearest to american: doomed, consequently, cell, ecb, beehives, mountaineers, islas, laborious,
# Nearest to six: parity, no, alou, concerning, heh, judah, artefacts, insulation,
# Nearest to often: gepids, pogroms, igbo, toontown, hutu, millisecond, miho, suspicion,
# Nearest to operating: sorcerer, apostrophe, pontifex, tautology, rocco, muharram, boii, balsam,
# Nearest to engineering: selecting, orchestral, buzz, foes, autobiography, dba, berghouata, pseudoephedrine,
# Nearest to governor: catalina, nhl, medusa, isdn, colombian, cyprinus, cvn, commenting,
# Nearest to except: wronged, bdsm, lotte, panzer, neutralise, announcement, eg, telephus,
# Nearest to writers: resettle, yiddish, wrestled, helvetii, endothermy, zweibr, weh, amis,
# Nearest to pope: lefkow, simulates, iraq, charger, kapor, wonderswan, auteurism, eustathius,
# Nearest to universe: mojave, pride, pulp, corresponds, daimyo, niggle, edouard, tracking,
# Nearest to discovered: reductive, ablett, sine, screwball, live, boost, cuckoo, snowboarding,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4640 0.0292 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4025 0.0281 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3437 0.0279 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2165 0.0279 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2216 0.0280 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1656 0.0277 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0880 0.0278 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0517 0.0280 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0137 0.0279 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9703 0.0278 sec/batch
# Nearest to were: founded, precisely, introducing, independently, alternatives, remember, monarch, checkers,
# Nearest to been: constituent, nine, northwest, nonmetallic, wept, ceeac, reappeared, hereditary,
# Nearest to by: limiting, through, scriptures, july, travelin, dumb, fully, chronometers,
# Nearest to i: correct, inaccurate, overweight, shop, ipv, factors, signing, miracles,
# Nearest to d: raoul, institutions, frysl, approximately, apart, deponent, quadi, sydney,
# Nearest to american: doomed, consequently, cell, ecb, de, will, salon, controversy,
# Nearest to six: parity, no, concerning, estimated, tension, alou, heh, artefacts,
# Nearest to often: pogroms, igbo, wild, toontown, suspicion, hutu, hide, gepids,
# Nearest to operating: apostrophe, sorcerer, pontifex, definition, protection, cabinet, notice, craig,
# Nearest to engineering: selecting, orchestral, autobiography, foes, buzz, dba, nahum, genome,
# Nearest to governor: catalina, isdn, nhl, colombian, commenting, obstetrician, information, advisor,
# Nearest to except: wronged, lotte, announcement, bdsm, error, eg, quadi, pursued,
# Nearest to writers: endothermy, resettle, yiddish, zweibr, weh, halved, formula, ring,
# Nearest to pope: lefkow, iraq, charger, simulates, consort, eustathius, neurophysiological, encephalopathies,
# Nearest to universe: mojave, corresponds, pride, fat, pulp, tracking, directly, edouard,
# Nearest to discovered: ablett, sine, live, boost, ducal, stochastic, reductive, methodically,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9139 0.0289 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9181 0.0280 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8930 0.0280 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8575 0.0280 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8240 0.0278 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8305 0.0281 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7884 0.0280 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7926 0.0281 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7825 0.0281 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7975 0.0281 sec/batch
# Nearest to were: remember, precisely, cerezo, introducing, checkers, alternatives, monarch, hildegard,
# Nearest to been: constituent, northwest, nonmetallic, techniques, reappeared, wept, ceeac, incarceration,
# Nearest to by: limiting, dumb, through, scriptures, enlightenment, fully, july, travelin,
# Nearest to i: correct, inaccurate, overweight, ipv, miracles, sri, shop, signing,
# Nearest to d: raoul, institutions, frysl, unforgiven, feast, sukkah, quadi, surviving,
# Nearest to american: doomed, consequently, nine, de, salon, beehives, islas, ecb,
# Nearest to six: parity, heh, estimated, artefacts, concerning, no, gnostics, detailing,
# Nearest to often: pogroms, suspicion, hutu, igbo, toontown, gepids, millisecond, outta,
# Nearest to operating: apostrophe, pontifex, sorcerer, cabinet, definition, tautology, heterosexual, conferences,
# Nearest to engineering: selecting, orchestral, foes, autobiography, buzz, genome, profession, depredations,
# Nearest to governor: catalina, isdn, commenting, nhl, withdraw, colombian, advisor, false,
# Nearest to except: wronged, bdsm, lotte, announcement, pursued, error, quadi, eg,
# Nearest to writers: endothermy, weh, yiddish, resettle, zweibr, formula, macarthur, wrestled,
# Nearest to pope: iraq, lefkow, charger, simulates, eustathius, troth, consort, geo,
# Nearest to universe: mojave, corresponds, pride, pulp, fat, edouard, lieutenant, tracking,
# Nearest to discovered: sine, live, ablett, ducal, boost, methodically, stochastic, athanasius,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8088 0.0290 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7330 0.0280 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7220 0.0280 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7288 0.0279 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7533 0.0281 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6825 0.0280 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6807 0.0282 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7246 0.0279 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7065 0.0279 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6573 0.0278 sec/batch
# Nearest to were: remember, cerezo, checkers, had, precisely, boundaries, alternatives, seduction,
# Nearest to been: northwest, constituent, nonmetallic, techniques, reappeared, incarceration, ceeac, wept,
# Nearest to by: dumb, limiting, enlightenment, scriptures, july, travelin, gameplay, through,
# Nearest to i: ipv, overweight, inaccurate, correct, miracles, shop, ibn, sri,
# Nearest to d: raoul, actor, physicist, composer, unforgiven, sydney, frysl, laureate,
# Nearest to american: nine, doomed, de, beehives, consequently, salon, grande, bacteriologist,
# Nearest to six: parity, four, seven, heh, artefacts, politician, two, births,
# Nearest to often: hutu, igbo, pogroms, suspicion, gepids, outta, specialists, lasse,
# Nearest to operating: apostrophe, pontifex, sorcerer, tautology, heterosexual, betray, heywood, morey,
# Nearest to engineering: orchestral, selecting, foes, buzz, autobiography, genome, depredations, profession,
# Nearest to governor: catalina, isdn, commenting, advisor, nhl, withdraw, colombian, medusa,
# Nearest to except: wronged, bdsm, lotte, pursued, domingue, error, panzer, eg,
# Nearest to writers: resettle, endothermy, weh, yiddish, zweibr, sinister, wrestled, teamsters,
# Nearest to pope: iraq, lefkow, charger, consort, eustathius, jpl, troth, condensed,
# Nearest to universe: mojave, corresponds, pride, fat, edouard, pulp, dominique, tracking,
# Nearest to discovered: sine, live, ablett, athanasius, methodically, ducal, boost, stochastic,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6892 0.0288 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6554 0.0279 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6120 0.0279 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6360 0.0281 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6423 0.0280 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6227 0.0278 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5721 0.0210 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5378 0.0281 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5240 0.0280 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5085 0.0280 sec/batch
# Nearest to were: remember, had, cerezo, checkers, seduction, boundaries, zimbabwean, monarch,
# Nearest to been: nonmetallic, northwest, reappeared, incarceration, ceeac, constituent, techniques, wept,
# Nearest to by: dumb, limiting, enlightenment, scriptures, crossings, vertex, travelin, gifford,
# Nearest to i: ipv, overweight, inaccurate, miracles, colan, correct, sri, ibn,
# Nearest to d: raoul, physicist, composer, laureate, actor, chemist, author, austrian,
# Nearest to american: nine, doomed, de, beehives, david, actress, salon, one,
# Nearest to six: parity, seven, four, politician, two, five, b, births,
# Nearest to often: gepids, hutu, specialists, igbo, lasse, suspicion, outta, technologies,
# Nearest to operating: tautology, sorcerer, computer, apostrophe, embedded, pontifex, betray, definition,
# Nearest to engineering: selecting, orchestral, buzz, genome, depredations, foes, autobiography, shoestring,
# Nearest to governor: catalina, advisor, colombian, nhl, san, isdn, withdraw, medusa,
# Nearest to except: wronged, bdsm, lotte, domingue, pursued, sane, error, panzer,
# Nearest to writers: resettle, endothermy, zweibr, weh, yiddish, cassiopeia, malory, sinister,
# Nearest to pope: iraq, lefkow, consort, charger, necker, troth, eustathius, manfred,
# Nearest to universe: mojave, corresponds, edouard, fat, pride, dominique, tin, tyre,
# Nearest to discovered: sine, ablett, live, athanasius, methodically, reductive, cuckoo, stochastic,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5113 0.0289 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5019 0.0279 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4773 0.0279 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5213 0.0279 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4982 0.0279 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4620 0.0281 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4529 0.0278 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4117 0.0278 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4242 0.0280 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4224 0.0279 sec/batch
# Nearest to were: remember, had, checkers, cerezo, boundaries, zimbabwean, clam, seduction,
# Nearest to been: nonmetallic, constituent, northwest, leena, incarceration, hindus, reappeared, ceeac,
# Nearest to by: dumb, limiting, vertex, nike, gifford, enlightenment, scriptures, travelin,
# Nearest to i: ipv, overweight, miracles, inaccurate, colan, ibn, correct, sri,
# Nearest to d: raoul, physicist, laureate, composer, chemist, actor, author, unforgiven,
# Nearest to american: nine, doomed, bacteriologist, de, islas, beehives, salon, nanak,
# Nearest to six: parity, four, seven, alou, two, heh, five, estimated,
# Nearest to often: hutu, gepids, lasse, specialists, technologies, picture, suspicion, hearing,
# Nearest to operating: tautology, computer, sorcerer, apostrophe, embedded, pontifex, applications, betray,
# Nearest to engineering: selecting, orchestral, genome, buzz, autobiography, depredations, foes, rattlesnake,
# Nearest to governor: catalina, colombian, nhl, advisor, withdraw, san, bobbing, bastion,
# Nearest to except: wronged, bdsm, domingue, panzer, lotte, pursued, error, sane,
# Nearest to writers: zweibr, endothermy, resettle, cassiopeia, weh, malory, undisturbed, yiddish,
# Nearest to pope: iraq, lefkow, consort, charger, troth, leicestershire, caldwell, auteurism,
# Nearest to universe: mojave, corresponds, interpret, fat, synonymous, dominique, cab, edouard,
# Nearest to discovered: sine, ablett, stochastic, live, methodically, cuckoo, athanasius, graphs,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4478 0.0288 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4105 0.0279 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4355 0.0280 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4080 0.0280 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4268 0.0279 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4499 0.0279 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3918 0.0280 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4005 0.0279 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3933 0.0280 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3804 0.0279 sec/batch
# Nearest to were: had, remember, checkers, cerezo, clam, zimbabwean, monarch, seduction,
# Nearest to been: nonmetallic, incarceration, leena, constituent, hereditary, disorder, reappeared, hindus,
# Nearest to by: dumb, limiting, nike, travelin, vertex, abstract, dap, legate,
# Nearest to i: overweight, ipv, miracles, inaccurate, colan, parody, correct, ibn,
# Nearest to d: raoul, physicist, laureate, composer, chemist, unforgiven, von, actor,
# Nearest to american: nine, doomed, bacteriologist, islas, de, salon, barkley, beehives,
# Nearest to six: parity, four, seven, two, five, politician, alou, one,
# Nearest to often: hutu, gepids, spin, suspicion, picture, technologies, noticing, lasse,
# Nearest to operating: computer, tautology, embedded, sorcerer, apostrophe, applications, implementing, pontifex,
# Nearest to engineering: selecting, genome, orchestral, buzz, sciences, rattlesnake, shoestring, autobiography,
# Nearest to governor: catalina, withdraw, protectorate, colombian, advisor, appointed, nhl, bastion,
# Nearest to except: wronged, bdsm, domingue, error, littering, lotte, energies, pursued,
# Nearest to writers: zweibr, resettle, endothermy, cassiopeia, yiddish, palliative, undisturbed, weh,
# Nearest to pope: iraq, lefkow, consort, caldwell, troth, eustathius, leicestershire, charger,
# Nearest to universe: corresponds, mojave, interpret, fat, synonymous, kabbalists, cab, everyone,
# Nearest to discovered: sine, ablett, stochastic, methodically, graphs, cuckoo, reductive, live,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3790 0.0288 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3942 0.0279 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3664 0.0280 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3744 0.0278 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4059 0.0280 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3528 0.0279 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3969 0.0279 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4005 0.0278 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3055 0.0279 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3337 0.0279 sec/batch
# Nearest to were: had, cerezo, checkers, remember, clam, monarch, zimbabwean, became,
# Nearest to been: nonmetallic, hereditary, constituent, incarceration, leena, northwest, ceeac, undecidability,
# Nearest to by: dumb, limiting, travelin, july, crossings, nike, legate, abdul,
# Nearest to i: parody, overweight, colan, inaccurate, correct, ipv, miracles, lio,
# Nearest to d: raoul, physicist, laureate, composer, chemist, unforgiven, frysl, von,
# Nearest to american: bacteriologist, nine, doomed, islas, barkley, de, nanak, beehives,
# Nearest to six: parity, four, seven, five, two, alou, one, est,
# Nearest to often: suspicion, hutu, noticing, gepids, picture, hearing, specialists, cuteness,
# Nearest to operating: computer, tautology, embedded, sorcerer, intel, technologies, mode, applications,
# Nearest to engineering: selecting, genome, sciences, orchestral, buzz, rattlesnake, shoestring, decoders,
# Nearest to governor: withdraw, appointed, advisor, catalina, colombian, protectorate, bastion, nhl,
# Nearest to except: wronged, domingue, bdsm, error, energies, lotte, procuring, littering,
# Nearest to writers: zweibr, resettle, yiddish, cassiopeia, endothermy, malory, weh, heather,
# Nearest to pope: iraq, lefkow, consort, eustathius, caldwell, troth, bulgakov, maternal,
# Nearest to universe: corresponds, interpret, kabbalists, mojave, fat, synonymous, propagate, sadd,
# Nearest to discovered: sine, stochastic, graphs, ablett, methodically, cuckoo, reductive, athanasius,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3491 0.0289 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2918 0.0281 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3597 0.0280 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4032 0.0281 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3741 0.0279 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3042 0.0280 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2961 0.0279 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3186 0.0280 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2217 0.0280 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3059 0.0280 sec/batch
# Nearest to were: had, cerezo, clam, checkers, remember, zimbabwean, monarch, became,
# Nearest to been: nonmetallic, hereditary, incarceration, constituent, ceeac, leena, disorder, qualcomm,
# Nearest to by: dumb, limiting, july, abdul, travelin, crossings, legate, nike,
# Nearest to i: parody, colan, overweight, correct, miracles, lio, inaccurate, cousin,
# Nearest to d: raoul, physicist, laureate, chemist, composer, actor, astronomer, zoologist,
# Nearest to american: nine, bacteriologist, barkley, actor, islas, rgen, doomed, actress,
# Nearest to six: parity, four, seven, two, five, one, alou, politician,
# Nearest to often: suspicion, hutu, hide, fittest, gepids, hearing, horoscopes, noticing,
# Nearest to operating: computer, embedded, tautology, sorcerer, intel, developer, dos, mode,
# Nearest to engineering: selecting, sciences, genome, buzz, shoestring, orchestral, decoders, rattlesnake,
# Nearest to governor: withdraw, appointed, protectorate, sejm, colombian, catalina, voter, advisor,
# Nearest to except: wronged, domingue, bdsm, error, sane, energies, littering, pendants,
# Nearest to writers: yiddish, zweibr, cassiopeia, amis, endothermy, heather, panpsychism, malory,
# Nearest to pope: lefkow, iraq, caldwell, eustathius, consort, maternal, antiquark, bulgakov,
# Nearest to universe: corresponds, interpret, kabbalists, synonymous, fat, nature, mojave, everyone,
# Nearest to discovered: sine, stochastic, ablett, graphs, rectangle, methodically, athanasius, reductive,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3171 0.0288 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2910 0.0279 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3599 0.0134 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2644 0.0279 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2255 0.0281 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2026 0.0280 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2467 0.0282 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2191 0.0279 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2221 0.0278 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1937 0.0278 sec/batch
# Nearest to were: had, cerezo, clam, remember, checkers, zimbabwean, became, capturing,
# Nearest to been: nonmetallic, hereditary, incarceration, leena, vitality, disorder, narcolepsy, hindus,
# Nearest to by: crossings, dumb, limiting, abdul, legate, july, ghul, benno,
# Nearest to i: parody, lio, cousin, colan, overweight, inaccurate, dukes, correct,
# Nearest to d: raoul, physicist, laureate, chemist, composer, zoologist, actor, astronomer,
# Nearest to american: nine, bacteriologist, barkley, islas, nanak, snooker, doomed, rebecca,
# Nearest to six: parity, four, five, two, seven, one, alou, est,
# Nearest to often: hutu, facets, suspicion, hearing, horoscopes, hide, noticing, gepids,
# Nearest to operating: computer, embedded, intel, tautology, sorcerer, dos, developer, technologies,
# Nearest to engineering: selecting, sciences, buzz, genome, decoders, shoestring, orchestral, instated,
# Nearest to governor: withdraw, sejm, appointed, colombian, catalina, voter, candidacy, bastion,
# Nearest to except: domingue, wronged, bdsm, sane, error, littering, pendants, energies,
# Nearest to writers: zweibr, yiddish, cassiopeia, resettle, endothermy, amis, panpsychism, undisturbed,
# Nearest to pope: lefkow, caldwell, iraq, consort, eustathius, maternal, antiquark, bulgakov,
# Nearest to universe: corresponds, interpret, kabbalists, synonymous, nature, fat, mojave, everyone,
# Nearest to discovered: sine, ablett, stochastic, rectangle, methodically, concubine, rheology, reductive,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2401 0.0291 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2418 0.0281 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2330 0.0279 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1058 0.0280 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1745 0.0279 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1921 0.0279 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1670 0.0278 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1925 0.0280 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1904 0.0279 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1609 0.0279 sec/batch
# Nearest to were: had, clam, cerezo, remember, checkers, became, stayed, capturing,
# Nearest to been: nonmetallic, hereditary, incarceration, qualcomm, vitality, disorder, seleucids, leena,
# Nearest to by: dumb, limiting, benno, jeane, abstract, reacts, abdul, crossings,
# Nearest to i: correct, parody, inaccurate, lio, overweight, cousin, we, dukes,
# Nearest to d: raoul, physicist, chemist, laureate, composer, zoologist, unforgiven, mortier,
# Nearest to american: barkley, bacteriologist, islas, nine, nanak, doomed, renderer, diego,
# Nearest to six: four, parity, five, two, seven, one, alou, zero,
# Nearest to often: facets, hide, horoscopes, hearing, hutu, millisecond, suspicion, fittest,
# Nearest to operating: embedded, computer, intel, tautology, sorcerer, dos, pdp, developer,
# Nearest to engineering: selecting, sciences, profession, decoders, genome, buzz, sabbatical, profile,
# Nearest to governor: withdraw, appointed, sejm, voter, colombian, catalina, bastion, candidacy,
# Nearest to except: domingue, wronged, sane, bdsm, error, littering, pendants, lotte,
# Nearest to writers: zweibr, yiddish, cassiopeia, resettle, endothermy, amis, dictionary, panpsychism,
# Nearest to pope: lefkow, iraq, caldwell, eustathius, maternal, consort, surviving, antiquark,
# Nearest to universe: corresponds, interpret, kabbalists, synonymous, nature, theories, frobenius, elsevier,
# Nearest to discovered: sine, stochastic, rectangle, reductive, ablett, methodically, centriole, graphs,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1570 0.0288 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1968 0.0279 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1682 0.0279 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1762 0.0279 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1727 0.0278 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1837 0.0279 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1928 0.0280 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1670 0.0278 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1347 0.0279 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2046 0.0279 sec/batch
# Nearest to were: had, clam, cerezo, checkers, stayed, became, remember, capturing,
# Nearest to been: nonmetallic, hereditary, incarceration, vitality, qualcomm, leena, undecidability, hindus,
# Nearest to by: dumb, limiting, july, legate, jeane, crossings, travelin, abstract,
# Nearest to i: parody, overweight, correct, carew, inaccurate, you, lio, colan,
# Nearest to d: raoul, physicist, composer, chemist, laureate, zoologist, mortier, theodor,
# Nearest to american: nine, bacteriologist, barkley, islas, nanak, ethnomusicologist, actor, doomed,
# Nearest to six: four, two, five, parity, seven, one, zero, alou,
# Nearest to often: facets, hide, hutu, horoscopes, suspicion, alveolar, types, fittest,
# Nearest to operating: embedded, intel, developer, computer, tautology, sorcerer, dos, unix,
# Nearest to engineering: sciences, selecting, decoders, profession, genome, instructional, buzz, entrepreneurs,
# Nearest to governor: appointed, sejm, withdraw, voter, candidacy, colombian, protectorate, advisor,
# Nearest to except: domingue, error, wronged, sane, bdsm, littering, bounded, energies,
# Nearest to writers: yiddish, zweibr, cassiopeia, resettle, dictionary, amis, page, endothermy,
# Nearest to pope: lefkow, eustathius, caldwell, iraq, consort, maternal, ratzinger, bulgakov,
# Nearest to universe: interpret, corresponds, kabbalists, synonymous, theories, frobenius, nature, souness,
# Nearest to discovered: sine, stochastic, rectangle, centriole, ablett, graphs, reductive, concubine,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1928 0.0288 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1439 0.0280 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1592 0.0279 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2041 0.0280 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1450 0.0280 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1296 0.0280 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1692 0.0280 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1356 0.0281 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2053 0.0281 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2075 0.0280 sec/batch
# Nearest to were: had, clam, cerezo, stayed, checkers, became, eudora, capturing,
# Nearest to been: hereditary, incarceration, nonmetallic, vitality, kirkcaldy, seleucids, hindus, leena,
# Nearest to by: legate, gifford, dumb, abdul, abstract, july, jeane, limiting,
# Nearest to i: parody, dukes, carew, you, lio, inaccurate, sentence, colan,
# Nearest to d: raoul, laureate, physicist, chemist, zoologist, composer, actor, mortier,
# Nearest to american: nine, bacteriologist, barkley, islas, actor, ethnomusicologist, snooker, nanak,
# Nearest to six: four, five, two, one, seven, parity, zero, three,
# Nearest to often: facets, hutu, hide, suspicion, millisecond, alveolar, profanity, hecate,
# Nearest to operating: embedded, jre, tautology, intel, dos, computer, sorcerer, tasking,
# Nearest to engineering: sciences, selecting, profession, decoders, instructional, buzz, entrepreneurs, genome,
# Nearest to governor: appointed, sejm, withdraw, candidacy, voter, colombian, mountaineer, protectorate,
# Nearest to except: domingue, wronged, sane, error, littering, energies, valderrama, lotte,
# Nearest to writers: zweibr, yiddish, amis, cassiopeia, dictionary, resettle, page, classics,
# Nearest to pope: lefkow, iraq, eustathius, caldwell, bulgakov, ch, iii, maternal,
# Nearest to universe: interpret, kabbalists, corresponds, synonymous, frobenius, councils, nature, souness,
# Nearest to discovered: sine, centriole, stochastic, concubine, ablett, reductive, rectangle, graphs,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2267 0.0288 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1238 0.0279 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1567 0.0279 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1347 0.0279 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0520 0.0280 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1474 0.0281 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1730 0.0279 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1380 0.0279 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1707 0.0058 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1141 0.0278 sec/batch
# Nearest to were: had, cerezo, clam, stayed, checkers, became, remember, capturing,
# Nearest to been: hereditary, nonmetallic, incarceration, leena, vitality, kirkcaldy, seleucids, qualcomm,
# Nearest to by: legate, abdul, limiting, gifford, dumb, crossings, polemics, abstract,
# Nearest to i: you, parody, sentence, we, lio, carew, inaccurate, dukes,
# Nearest to d: raoul, laureate, composer, chemist, physicist, zoologist, mortier, actor,
# Nearest to american: nine, islas, bacteriologist, barkley, ethnomusicologist, snooker, actor, nanak,
# Nearest to six: four, two, five, seven, one, parity, zero, three,
# Nearest to often: hide, facets, hutu, hecate, millisecond, flutes, suspicion, profanity,
# Nearest to operating: embedded, jre, tasking, developer, sorcerer, intel, unix, computer,
# Nearest to engineering: sciences, selecting, profession, decoders, instructional, entrepreneurs, actuarial, genome,
# Nearest to governor: appointed, sejm, candidacy, voter, withdraw, representatives, protectorate, colombian,
# Nearest to except: domingue, wronged, sane, error, littering, bdsm, lotte, valderrama,
# Nearest to writers: amis, yiddish, zweibr, resettle, cassiopeia, dictionary, page, panpsychism,
# Nearest to pope: lefkow, iraq, eustathius, caldwell, paekche, ch, troth, bulgakov,
# Nearest to universe: interpret, kabbalists, corresponds, synonymous, councils, nature, frobenius, theories,
# Nearest to discovered: concubine, sine, stochastic, centriole, fptp, methodically, rectangle, ablett,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0861 0.0290 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0763 0.0280 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0852 0.0280 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0688 0.0280 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0829 0.0280 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0453 0.0279 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1143 0.0279 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1076 0.0278 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1269 0.0280 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0231 0.0277 sec/batch
# Nearest to were: had, cerezo, checkers, clam, stayed, became, dragged, tribes,
# Nearest to been: nonmetallic, hereditary, incarceration, qualcomm, seleucids, vitality, leena, disorder,
# Nearest to by: legate, limiting, dumb, gifford, abstract, abdul, mena, through,
# Nearest to i: you, dukes, lio, parody, carew, sentence, we, inaccurate,
# Nearest to d: raoul, chemist, zoologist, laureate, composer, mortier, physicist, biog,
# Nearest to american: islas, barkley, nine, bacteriologist, ethnomusicologist, nanak, snooker, misfits,
# Nearest to six: four, two, five, seven, parity, one, zero, three,
# Nearest to often: facets, millisecond, profanity, hecate, hide, suspicion, hutu, horoscopes,
# Nearest to operating: embedded, tasking, jre, sorcerer, developer, computer, memory, intel,
# Nearest to engineering: sciences, selecting, decoders, profession, instructional, actuarial, entrepreneurs, genome,
# Nearest to governor: sejm, appointed, candidacy, withdraw, voter, representatives, mountaineer, catalina,
# Nearest to except: domingue, error, wronged, bdsm, sane, littering, street, lotte,
# Nearest to writers: amis, resettle, zweibr, yiddish, cassiopeia, dictionary, page, panpsychism,
# Nearest to pope: lefkow, iraq, caldwell, eustathius, ch, iii, paekche, bulgakov,
# Nearest to universe: synonymous, kabbalists, interpret, corresponds, souness, frobenius, theories, councils,
# Nearest to discovered: centriole, stochastic, sine, concubine, fptp, ablett, rectangle, reductive,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0103 0.0290 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0221 0.0279 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0323 0.0279 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0801 0.0277 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0630 0.0278 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0480 0.0279 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0799 0.0277 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0859 0.0277 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0580 0.0279 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0487 0.0279 sec/batch
# Nearest to were: had, checkers, stayed, clam, cerezo, became, dragged, condone,
# Nearest to been: hereditary, nonmetallic, qualcomm, incarceration, vitality, undecidability, disorder, seleucids,
# Nearest to by: abstract, dumb, limiting, legate, a, polemics, gifford, the,
# Nearest to i: you, we, parody, sentence, carew, dukes, lio, inaccurate,
# Nearest to d: raoul, chemist, laureate, mortier, zoologist, composer, physicist, biog,
# Nearest to american: islas, barkley, ethnomusicologist, nanak, snooker, nine, doomed, bacteriologist,
# Nearest to six: four, two, five, seven, one, parity, three, zero,
# Nearest to often: facets, diminution, profanity, hide, habitually, millisecond, hecate, suspicion,
# Nearest to operating: embedded, tasking, jre, tautology, intel, sorcerer, dos, myeloid,
# Nearest to engineering: sciences, selecting, profession, instructional, actuarial, decoders, structural, underpinning,
# Nearest to governor: candidacy, sejm, appointed, voter, withdraw, catalina, representatives, mountaineer,
# Nearest to except: domingue, error, street, bdsm, lotte, littering, wronged, sane,
# Nearest to writers: amis, resettle, zweibr, dictionary, cassiopeia, yiddish, page, weh,
# Nearest to pope: lefkow, iraq, eustathius, caldwell, ch, troth, bulgakov, paekche,
# Nearest to universe: interpret, synonymous, kabbalists, corresponds, theories, souness, councils, nature,
# Nearest to discovered: centriole, stochastic, sine, reductive, fptp, ablett, concubine, rectangle,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0866 0.0289 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0742 0.0279 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0712 0.0279 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0618 0.0278 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0897 0.0281 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0555 0.0279 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0605 0.0278 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0375 0.0279 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0749 0.0279 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0722 0.0280 sec/batch
# Nearest to were: had, stayed, became, clam, cerezo, checkers, condone, tribes,
# Nearest to been: hereditary, incarceration, nonmetallic, seleucids, qualcomm, vitality, disorder, personally,
# Nearest to by: legate, the, limiting, july, gifford, dumb, abdul, a,
# Nearest to i: you, carew, parody, dukes, lio, sentence, we, inaccurate,
# Nearest to d: raoul, zoologist, chemist, physicist, composer, laureate, biog, frysl,
# Nearest to american: islas, barkley, ethnomusicologist, nanak, misfits, bacteriologist, doomed, musician,
# Nearest to six: four, two, five, seven, one, parity, three, zero,
# Nearest to often: facets, grunge, hecate, profanity, mallets, hide, provocation, millisecond,
# Nearest to operating: embedded, tasking, jre, intel, dos, unix, tautology, developer,
# Nearest to engineering: sciences, selecting, profession, instructional, actuarial, asset, decoders, genome,
# Nearest to governor: candidacy, appointed, sejm, voter, representatives, withdraw, executive, mountaineer,
# Nearest to except: domingue, error, street, wronged, bdsm, sane, continues, conveniently,
# Nearest to writers: resettle, amis, zweibr, cassiopeia, dictionary, weh, inconsistencies, classics,
# Nearest to pope: lefkow, eustathius, ch, caldwell, iraq, troth, paekche, uscis,
# Nearest to universe: interpret, kabbalists, synonymous, theories, souness, corresponds, frobenius, councils,
# Nearest to discovered: centriole, stochastic, concubine, sine, reductive, fptp, ablett, chah,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0360 0.0288 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0015 0.0278 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0510 0.0277 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0621 0.0280 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0737 0.0281 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0999 0.0280 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1241 0.0279 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0549 0.0278 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0198 0.0278 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0417 0.0277 sec/batch
# Nearest to were: had, clam, checkers, stayed, became, cerezo, dragged, eudora,
# Nearest to been: hereditary, incarceration, qualcomm, nonmetallic, vitality, seleucids, leena, kirkcaldy,
# Nearest to by: legate, gifford, limiting, dumb, july, abdul, dictates, artificially,
# Nearest to i: you, we, carew, parody, sentence, lio, indicative, me,
# Nearest to d: raoul, laureate, physicist, chemist, zoologist, composer, mortier, biog,
# Nearest to american: islas, barkley, ethnomusicologist, bacteriologist, takamine, misfits, actor, snooker,
# Nearest to six: four, two, five, seven, one, parity, three, zero,
# Nearest to often: facets, millisecond, grunge, profanity, nicky, habitually, horticulture, provocation,
# Nearest to operating: tasking, embedded, jre, intel, unix, interoperate, sorcerer, multitasking,
# Nearest to engineering: sciences, instructional, profession, selecting, actuarial, asset, decoders, underpinning,
# Nearest to governor: candidacy, appointed, sejm, voter, mountaineer, representatives, withdraw, executive,
# Nearest to except: domingue, error, wronged, continues, sane, codepoint, street, bdsm,
# Nearest to writers: amis, zweibr, dictionary, resettle, classics, page, cassiopeia, novelists,
# Nearest to pope: lefkow, eustathius, ch, caldwell, troth, iraq, iii, andreessen,
# Nearest to universe: interpret, kabbalists, synonymous, theories, corresponds, souness, frobenius, councils,
# Nearest to discovered: concubine, centriole, stochastic, sine, fptp, ablett, reductive, pluto,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9830 0.0289 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0259 0.0279 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0309 0.0278 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0179 0.0279 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0661 0.0279 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0483 0.0261 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0109 0.0280 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9927 0.0279 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0216 0.0281 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9686 0.0279 sec/batch
# Nearest to were: had, clam, cerezo, checkers, stayed, became, tribes, dragged,
# Nearest to been: hereditary, qualcomm, nonmetallic, incarceration, seleucids, leena, kirkcaldy, vitality,
# Nearest to by: the, legate, limiting, eighth, a, in, through, july,
# Nearest to i: you, carew, we, lio, sentence, dukes, me, parody,
# Nearest to d: raoul, physicist, composer, chemist, laureate, harpsichordist, zoologist, albemarle,
# Nearest to american: islas, ethnomusicologist, nine, barkley, snooker, actor, bacteriologist, musician,
# Nearest to six: four, two, five, seven, one, three, zero, eight,
# Nearest to often: facets, grunge, habitually, millisecond, provocation, horticulture, nicky, hecate,
# Nearest to operating: embedded, tasking, jre, intel, unix, interoperate, gnat, developer,
# Nearest to engineering: sciences, profession, actuarial, instructional, selecting, asset, decoders, structural,
# Nearest to governor: candidacy, appointed, sejm, voter, mountaineer, lieutenant, pat, executive,
# Nearest to except: domingue, lotte, street, continues, codepoint, error, bdsm, o,
# Nearest to writers: amis, resettle, dictionary, zweibr, classics, novelists, cassiopeia, page,
# Nearest to pope: lefkow, eustathius, caldwell, iii, ch, andreessen, iraq, troth,
# Nearest to universe: interpret, kabbalists, synonymous, theories, corresponds, councils, souness, beings,
# Nearest to discovered: concubine, centriole, stochastic, pluto, sine, ablett, chah, fptp,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9926 0.0289 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9354 0.0280 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0171 0.0277 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0117 0.0278 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0256 0.0279 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9928 0.0277 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9107 0.0278 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9765 0.0280 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9203 0.0278 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9791 0.0278 sec/batch
# Nearest to were: had, stayed, clam, became, checkers, cerezo, these, tribes,
# Nearest to been: hereditary, qualcomm, incarceration, nonmetallic, vitality, seleucids, leena, narcolepsy,
# Nearest to by: the, a, eighth, limiting, dumb, in, zircon, through,
# Nearest to i: you, we, carew, me, indicative, sentence, lio, dukes,
# Nearest to d: raoul, frysl, biog, zoologist, mortier, physicist, chemist, laureate,
# Nearest to american: islas, barkley, takamine, ethnomusicologist, tropical, snooker, renderer, nanak,
# Nearest to six: four, two, five, one, seven, zero, three, parity,
# Nearest to often: facets, grunge, profanity, nicky, mallets, horticulture, hecate, provocation,
# Nearest to operating: embedded, tasking, jre, intel, unix, interoperate, myeloid, sorcerer,
# Nearest to engineering: sciences, instructional, profession, actuarial, copenhagen, asset, vassar, selecting,
# Nearest to governor: candidacy, appointed, sejm, voter, executive, mountaineer, lieutenant, pat,
# Nearest to except: domingue, continues, lotte, street, places, o, codepoint, error,
# Nearest to writers: resettle, amis, dictionary, zweibr, inconsistencies, classics, page, vulnerability,
# Nearest to pope: lefkow, eustathius, iii, ch, caldwell, ratzinger, gregory, andreessen,
# Nearest to universe: interpret, synonymous, theories, kabbalists, corresponds, souness, beings, cosmic,
# Nearest to discovered: centriole, concubine, stochastic, sine, chah, pluto, ablett, fptp,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9735 0.0289 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0003 0.0279 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9611 0.0280 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0139 0.0279 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0438 0.0279 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9536 0.0279 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0057 0.0277 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9973 0.0278 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9788 0.0279 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0094 0.0278 sec/batch
# Nearest to were: had, stayed, became, checkers, clam, these, dragged, inactive,
# Nearest to been: hereditary, qualcomm, incarceration, vitality, leena, was, nonmetallic, kirkcaldy,
# Nearest to by: a, the, eighth, dictates, abstract, zircon, polemics, july,
# Nearest to i: you, me, carew, we, parody, do, sentence, want,
# Nearest to d: raoul, harpsichordist, physicist, chemist, zoologist, laureate, albemarle, composer,
# Nearest to american: ethnomusicologist, islas, actor, bacteriologist, snooker, musician, nine, barkley,
# Nearest to six: four, five, two, one, seven, zero, three, eight,
# Nearest to often: mallets, grunge, nicky, profanity, facets, habitually, horticulture, hecate,
# Nearest to operating: embedded, tasking, jre, unix, intel, sorcerer, myeloid, tautology,
# Nearest to engineering: sciences, instructional, actuarial, profession, asset, structural, decoders, genome,
# Nearest to governor: candidacy, appointed, sejm, voter, mountaineer, executive, counties, pat,
# Nearest to except: domingue, places, continues, street, codepoint, o, littering, lotte,
# Nearest to writers: amis, resettle, dictionary, inconsistencies, friendships, zweibr, classics, page,
# Nearest to pope: eustathius, lefkow, caldwell, ch, iii, gregory, ratzinger, condensed,
# Nearest to universe: interpret, theories, synonymous, kabbalists, corresponds, cosmic, souness, beings,
# Nearest to discovered: centriole, stochastic, concubine, reductive, chah, pluto, fptp, ablett,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0077 0.0288 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0024 0.0280 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9729 0.0279 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0035 0.0279 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0223 0.0279 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9942 0.0278 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9829 0.0280 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9698 0.0279 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9814 0.0277 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0007 0.0280 sec/batch
# Nearest to were: had, stayed, these, became, tribes, cerezo, independently, inactive,
# Nearest to been: hereditary, qualcomm, vitality, was, incarceration, northwest, kirkcaldy, nonmetallic,
# Nearest to by: the, a, legate, eighth, fragmentation, july, polemics, dictates,
# Nearest to i: you, me, carew, we, indicative, lio, want, sentence,
# Nearest to d: raoul, harpsichordist, albemarle, zoologist, physicist, laureate, chemist, frysl,
# Nearest to american: ethnomusicologist, islas, actor, snooker, takamine, bacteriologist, barkley, litas,
# Nearest to six: four, two, five, one, seven, three, zero, eight,
# Nearest to often: grunge, facets, atonality, habitually, mallets, neh, overtones, profanity,
# Nearest to operating: embedded, tasking, unix, jre, intel, cellphone, tautology, jlp,
# Nearest to engineering: sciences, instructional, actuarial, profession, asset, structural, dba, sabbatical,
# Nearest to governor: appointed, candidacy, executive, lieutenant, voter, representatives, sejm, chief,
# Nearest to except: domingue, continues, places, o, codepoint, street, error, bdsm,
# Nearest to writers: amis, resettle, dictionary, novelists, zweibr, friendships, vulnerability, inconsistencies,
# Nearest to pope: eustathius, lefkow, ch, iii, caldwell, gregory, ratzinger, bulgakov,
# Nearest to universe: interpret, theories, kabbalists, synonymous, beings, councils, cosmic, waterston,
# ...
# Nearest to american: snooker, takamine, ethnomusicologist, actor, lada, catholics, elucidated, reappraisal,
# Nearest to six: four, one, two, five, seven, three, eight, zero,
# Nearest to often: atonality, neh, and, underlined, most, nicky, violence, grunge,
# Nearest to operating: unix, netbsd, jlp, embedded, documented, briefly, tasking, kernel,
# Nearest to engineering: sciences, profession, actuarial, warangal, electromagnetism, instructional, depredations, guericke,
# Nearest to governor: lieutenant, candidacy, appointed, mountaineer, veto, bastion, dodos, counties,
# Nearest to except: continues, o, places, street, fidei, chelating, existed, myriads,
# Nearest to writers: novelists, winners, amis, births, entertainers, vulnerability, alumni, realaudio,
# Nearest to pope: nevers, celestine, eustathius, innocent, gregory, vii, ch, ratzinger,
# Nearest to universe: cosmic, unborn, disenfranchisement, corresponds, czechs, theories, beings, councils,
# Nearest to discovered: genomics, pluto, daimler, concubine, pepys, autoimmune, galileo, chah,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8502 0.0289 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8523 0.0279 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8603 0.0278 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8234 0.0280 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8667 0.0277 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8616 0.0280 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8643 0.0279 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8470 0.0282 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9050 0.0280 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8277 0.0279 sec/batch
# Nearest to were: had, became, these, period, have, depended, dragged, earlier,
# Nearest to been: was, have, decades, widely, occurred, ago, has, irregulars,
# Nearest to by: the, a, in, of, and, eighth, is, through,
# Nearest to i: you, me, t, everything, we, am, hernando, nothing,
# Nearest to d: raoul, frysl, laureate, albemarle, biog, physicist, tul, praetorius,
# Nearest to american: actor, ethnomusicologist, takamine, lada, snooker, catholics, reappraisal, elucidated,
# Nearest to six: four, one, two, five, seven, three, zero, eight,
# Nearest to often: neh, atonality, most, kaddish, or, mallets, dissonances, frequently,
# Nearest to operating: netbsd, unix, jlp, embedded, openstep, kernel, tasking, documented,
# Nearest to engineering: sciences, profession, asset, actuarial, guericke, depredations, warangal, electromagnetism,
# Nearest to governor: lieutenant, candidacy, appointed, mountaineer, veto, bastion, dodos, executive,
# Nearest to except: continues, o, places, fidei, existed, chelating, street, adar,
# Nearest to writers: novelists, amis, winners, entertainers, vulnerability, births, authors, fiction,
# Nearest to pope: nevers, celestine, eustathius, vii, gregory, ch, troth, achille,
# Nearest to universe: cosmic, disenfranchisement, unborn, czechs, cosmological, corresponds, councils, theories,
# Nearest to discovered: concubine, pluto, galileo, daimler, pepys, proven, stellar, chah,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8620 0.0289 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8449 0.0283 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8151 0.0281 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8397 0.0279 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8952 0.0281 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8468 0.0281 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9390 0.0279 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8884 0.0280 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9111 0.0279 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8069 0.0280 sec/batch
# Nearest to were: had, became, these, period, dragged, but, depended, some,
# Nearest to been: was, decades, have, widely, has, ago, irregulars, occurred,
# Nearest to by: the, a, in, of, and, eighth, for, important,
# Nearest to i: me, you, we, am, t, hernando, know, everything,
# Nearest to d: raoul, frysl, laureate, physicist, albemarle, biog, harpsichordist, tul,
# Nearest to american: actor, snooker, catholics, ethnomusicologist, lada, takamine, reappraisal, levantine,
# Nearest to six: four, one, two, five, seven, three, eight, zero,
# Nearest to often: most, neh, nicky, atonality, greatly, several, or, use,
# Nearest to operating: unix, netbsd, jlp, openstep, embedded, kernel, briefly, tasking,
# Nearest to engineering: sciences, depredations, profession, guericke, warangal, actuarial, asset, wellcome,
# Nearest to governor: lieutenant, candidacy, mountaineer, appointed, dodos, veto, executive, bastion,
# Nearest to except: continues, places, o, fidei, street, chelating, existed, concession,
# Nearest to writers: novelists, winners, births, amis, entertainers, philosophers, fiction, alumni,
# Nearest to pope: nevers, celestine, ch, gregory, vii, eustathius, troth, laodicea,
# Nearest to universe: cosmic, disenfranchisement, unborn, councils, czechs, beings, whoever, cosmological,
# Nearest to discovered: galileo, concubine, daimler, pluto, pepys, chah, relics, proven,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8040 0.0288 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8635 0.0277 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7764 0.0278 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8855 0.0280 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8527 0.0278 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8888 0.0278 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9026 0.0165 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8276 0.0279 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8349 0.0282 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8563 0.0280 sec/batch
# Nearest to were: had, but, these, they, some, period, depended, became,
# Nearest to been: was, have, decades, widely, irregulars, preserved, occurred, ago,
# Nearest to by: the, in, of, a, and, eighth, important, is,
# Nearest to i: me, you, am, we, hernando, nothing, everything, t,
# Nearest to d: raoul, laureate, albemarle, frysl, physicist, harpsichordist, cricketer, actor,
# Nearest to american: actor, snooker, catholics, ethnomusicologist, takamine, lada, nine, iroquois,
# Nearest to six: four, one, two, five, seven, three, eight, zero,
# Nearest to often: neh, most, atonality, dissonances, use, burmese, nicky, contrast,
# Nearest to operating: jlp, netbsd, unix, briefly, embedded, openstep, sorcerer, allison,
# Nearest to engineering: sciences, profession, depredations, warangal, heterogenous, guericke, actuarial, bioengineering,
# Nearest to governor: lieutenant, candidacy, mountaineer, appointed, bastion, executive, dodos, counties,
# Nearest to except: continues, places, o, street, fidei, chelating, concession, myriads,
# Nearest to writers: novelists, winners, entertainers, amis, births, alumni, philosophers, vulnerability,
# Nearest to pope: nevers, celestine, vii, gregory, troth, ch, eustathius, bulgakov,
# Nearest to universe: cosmic, unborn, beings, disenfranchisement, councils, czechs, theories, whoever,
# Nearest to discovered: concubine, daimler, pluto, relics, pepys, galileo, chah, stellar,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8313 0.0289 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8119 0.0279 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8030 0.0280 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8187 0.0279 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8476 0.0280 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8217 0.0278 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8758 0.0280 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7457 0.0280 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8182 0.0280 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8050 0.0278 sec/batch
# Nearest to were: had, these, but, have, depended, became, they, some,
# Nearest to been: was, have, decades, occurred, has, widely, reported, archeological,
# Nearest to by: the, a, in, of, and, is, important, eighth,
# Nearest to i: me, you, am, t, nothing, we, everything, know,
# Nearest to d: raoul, frysl, albemarle, tul, laureate, elcano, biog, colonizer,
# Nearest to american: catholics, levantine, ethnomusicologist, people, snooker, iroquois, reappraisal, lada,
# Nearest to six: four, one, two, five, seven, three, eight, zero,
# Nearest to often: neh, most, and, use, atonality, dissonances, several, greatly,
# Nearest to operating: jlp, unix, embedded, netbsd, allison, sorcerer, briefly, openstep,
# Nearest to engineering: sciences, engineers, bioengineering, guericke, profession, depredations, heterogenous, electromagnetism,
# Nearest to governor: lieutenant, candidacy, appointed, mountaineer, bastion, executive, dodos, veto,
# Nearest to except: continues, places, o, street, chelating, fidei, lotte, existed,
# Nearest to writers: novelists, winners, births, entertainers, vulnerability, alumni, amis, authors,
# Nearest to pope: celestine, nevers, gregory, vii, eustathius, ch, troth, bulgakov,
# Nearest to universe: cosmic, disenfranchisement, unborn, beings, cosmological, councils, czechs, theories,
# Nearest to discovered: concubine, proven, galileo, daimler, pepys, chah, relics, colourless,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7700 0.0287 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8181 0.0278 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8334 0.0279 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8393 0.0279 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8231 0.0277 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9099 0.0278 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8563 0.0278 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8254 0.0278 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8302 0.0281 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8305 0.0280 sec/batch
# Nearest to were: had, these, became, but, some, depended, have, settled,
# Nearest to been: was, have, decades, has, widely, occurred, used, ago,
# Nearest to by: the, a, of, in, and, is, important, s,
# Nearest to i: me, you, am, nothing, hernando, we, t, everything,
# Nearest to d: raoul, frysl, laureate, tul, albemarle, elcano, biog, cricketer,
# Nearest to american: ethnomusicologist, snooker, takamine, catholics, lada, actor, iroquois, reappraisal,
# Nearest to six: four, one, two, seven, five, three, eight, zero,
# Nearest to often: neh, most, atonality, any, several, flatted, dissonances, mallets,
# Nearest to operating: jlp, unix, netbsd, allison, embedded, sorcerer, tautology, briefly,
# Nearest to engineering: profession, sciences, bioengineering, warangal, guericke, depredations, electromagnetism, heterogenous,
# Nearest to governor: candidacy, lieutenant, appointed, mountaineer, bastion, executive, veto, counties,
# Nearest to except: continues, places, o, street, fidei, chelating, extend, lose,
# Nearest to writers: novelists, winners, births, authors, entertainers, vulnerability, amis, polymaths,
# Nearest to pope: celestine, nevers, gregory, vii, eustathius, troth, bulgakov, ch,
# Nearest to universe: cosmic, unborn, disenfranchisement, beings, czechs, councils, cosmological, whoever,
# Nearest to discovered: concubine, daimler, pepys, chah, colourless, stellar, proven, relics,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8695 0.0289 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8381 0.0279 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8190 0.0279 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8555 0.0279 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8532 0.0278 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8416 0.0282 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8369 0.0280 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8542 0.0278 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8099 0.0280 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8082 0.0279 sec/batch
# Nearest to were: had, became, depended, some, but, these, period, have,
# Nearest to been: was, have, decades, has, widely, since, occurred, irregulars,
# Nearest to by: the, a, in, of, and, is, to, important,
# Nearest to i: me, you, am, nothing, we, t, hernando, just,
# Nearest to d: frysl, raoul, tul, laureate, elcano, praetorius, biog, albemarle,
# Nearest to american: takamine, ethnomusicologist, reappraisal, lada, catholics, vehemently, snooker, iroquois,
# Nearest to six: four, one, five, two, three, seven, eight, zero,
# Nearest to often: most, neh, and, any, atonality, considered, in, or,
# Nearest to operating: jlp, unix, netbsd, allison, multitasking, briefly, sorcerer, tautology,
# Nearest to engineering: warangal, depredations, profession, asset, sciences, guericke, electromagnetism, instructional,
# Nearest to governor: lieutenant, candidacy, appointed, mountaineer, bastion, executive, counties, veto,
# Nearest to except: continues, o, places, fidei, chelating, street, all, lotte,
# Nearest to writers: novelists, winners, births, entertainers, polymaths, alumni, philosophers, vulnerability,
# Nearest to pope: celestine, gregory, nevers, vii, eustathius, troth, bulgakov, innocent,
# Nearest to universe: cosmic, disenfranchisement, unborn, councils, cosmological, czechs, mla, beings,
# Nearest to discovered: pepys, concubine, chah, galileo, daimler, stellar, discovery, relics,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8728 0.0289 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8211 0.0280 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9258 0.0280 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9022 0.0279 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8601 0.0278 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8435 0.0279 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7780 0.0278 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8428 0.0279 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7254 0.0278 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8637 0.0280 sec/batch
# Nearest to were: had, depended, some, these, independently, became, period, dragged,
# Nearest to been: was, have, decades, has, widely, since, occurred, reported,
# Nearest to by: the, a, in, of, and, s, is, through,
# Nearest to i: me, you, we, nothing, am, t, want, what,
# Nearest to d: raoul, frysl, laureate, elcano, tul, physicist, albemarle, cricketer,
# Nearest to american: actor, snooker, ethnomusicologist, takamine, reappraisal, catholics, lada, levantine,
# Nearest to six: four, one, five, seven, two, eight, three, zero,
# Nearest to often: most, neh, and, atonality, such, or, any, greatly,
# Nearest to operating: unix, jlp, netbsd, allison, sacra, briefly, schoolgirl, christendom,
# Nearest to engineering: sciences, profession, heterogenous, warangal, bioengineering, depredations, guericke, electromagnetism,
# Nearest to governor: lieutenant, mountaineer, candidacy, appointed, bastion, executive, counties, sitcom,
# Nearest to except: continues, o, places, fidei, chelating, street, all, lose,
# Nearest to writers: novelists, winners, philosophers, births, alumni, entertainers, authors, polymaths,
# Nearest to pope: nevers, celestine, gregory, vii, innocent, iii, troth, eustathius,
# Nearest to universe: unborn, cosmic, disenfranchisement, councils, czechs, beings, cosmological, whoever,
# Nearest to discovered: daimler, pepys, concubine, galileo, chah, surveyor, pluto, proven,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8225 0.0290 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8318 0.0278 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
